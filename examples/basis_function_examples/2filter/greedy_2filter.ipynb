# %%
import numpy as np
import matplotlib.pylab as plt
import healpy as hp
from lsst.sims.featureScheduler.modelObservatory import Model_observatory
from lsst.sims.featureScheduler.schedulers import Core_scheduler
from lsst.sims.featureScheduler.utils import standard_goals, calc_norm_factor
import lsst.sims.featureScheduler.basis_functions as bf
from lsst.sims.featureScheduler.surveys import (generate_dd_surveys, Greedy_survey,
                                                Blob_survey, Pairs_survey_scripted)
from lsst.sims.featureScheduler import sim_runner

from basic_survey import gen_greedy_surveys


import lsst.sims.maf.db as db
import lsst.sims.maf.utils as utils
import lsst.sims.maf.metrics as metrics
import lsst.sims.maf.slicers as slicers
import lsst.sims.maf.stackers as stackers
import lsst.sims.maf.metricBundles as metricBundles

import lsst.sims.maf.plots as plots

# %%
# The simple MAF plots to check what happend
def check_run(dbroot):
    bundleList = []
    for filtername in filters:
        metric = metrics.CountMetric(col='observationStartMJD')
        slicer = slicers.HealpixSlicer()
        sql = 'filter = "%s"' % filtername
        bundleList.append(metricBundles.MetricBundle(metric,slicer,sql,runName=dbroot,
                                                     plotFuncs=[plots.HealpixSkyMap()]))

    slicer =  slicer = slicers.HealpixSlicer(nside=64, latCol='altitude', lonCol='azimuth', useCache=False)
    sql=''
    metric = metrics.CountMetric(col='observationStartMJD')
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql, 
                                                 runName=dbroot, plotFuncs=[plots.LambertSkyMap()]))


    slicer = slicers.HourglassSlicer()
    sql=''
    metric = metrics.HourglassMetric(metricName='Hourglass')
    bundleList.append(metricBundles.MetricBundle(metric,slicer,sql,runName=dbroot))
    conn =  db.OpsimDatabase('%s.db' % dbroot)
    bd = metricBundles.makeBundlesDictFromList(bundleList)
    bg = metricBundles.MetricBundleGroup(bd, conn, outDir=dbroot, resultsDb=None)
    bg.runAll()
    bg.plotAll(closefigs=False)

# %%
def run_sim(runName, weights, filters, survey_length=30.):
    nside = 32
    surveys = gen_greedy_surveys(nside, add_DD=False, **weights, filters=filters)
    scheduler = Core_scheduler(surveys, nside=nside)
    observatory = Model_observatory(nside=nside)
    observatory, scheduler, observations = sim_runner(observatory, scheduler,
                                                      survey_length=survey_length,
                                                      filename='%s.db' % runName)
    check_run(runName)

# %%
#start with the default weights
runName = 'default'
weights = {'m5_weight': 3,
          'count_uniformity_weight' : 0.3,
           'slewtime_weight': 3., 'filter_change_weight': 4.}
filters = ['g', 'z']
run_sim(runName, weights, filters)
# Out:
# WARNING: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)" [astropy._erfa.core]
# WARNING:astropy:ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
# /Users/yoachim/gitRepos/sims_skybrightness_pre/python/lsst/sims/skybrightness_pre/SkyModelPre.py:370: UserWarning: Requested MJD between sunrise and sunset, returning closest maps
#   warnings.warn('Requested MJD between sunrise and sunset, returning closest maps')
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/modelObservatory/model_observatory.py:279: RuntimeWarning: invalid value encountered in less
#   slewtimes[np.where(slewtimes < 0)] = np.nan
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/modelObservatory/model_observatory.py:441: UserWarning: overriding requested rotSkyPos value
#   warnings.warn('overriding requested rotSkyPos value')
# progress = 100.1%Skipped 0 observations
# Flushed 0 observations from queue for being stale
# Completed 24621 observations
# ran in 8 min = 0.1 hours
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/sim_runner.py:98: UserWarning: Failed to get info about run, may need to run scons in some pacakges.
#   warnings.warn('Failed to get info about run, may need to run scons in some pacakges.')
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['observationStartMJD', 'night', 'altitude', 'azimuth', 'filter'].
# Found 24621 visits
# Running:  ['default_Count_observationStartMJD_HEAL']
# Completed metric generation.
# Running:  ['default_Hourglass_HOUR']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter = "g" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 15092 visits
# Running:  ['default_Count_observationStartMJD_g_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter = "z" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 9529 visits
# Running:  ['default_Count_observationStartMJD_z_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# Plotting complete.
# Plotting figures with "filter = "g"" constraint now.
# Plotting complete.
# Plotting figures with "filter = "z"" constraint now.
# Plotting complete.

# %%
#Now to ephasize slewtime
runName = 'HeavySlew'
weights = {'m5_weight': 3,
          'count_uniformity_weight' : 0.3,
           'slewtime_weight': 10., 'filter_change_weight': 4.}
filters = ['g', 'z']
run_sim(runName, weights, filters)
# Out:
# WARNING: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)" [astropy._erfa.core]
# WARNING:astropy:ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
# /Users/yoachim/gitRepos/sims_skybrightness_pre/python/lsst/sims/skybrightness_pre/SkyModelPre.py:370: UserWarning: Requested MJD between sunrise and sunset, returning closest maps
#   warnings.warn('Requested MJD between sunrise and sunset, returning closest maps')
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/modelObservatory/model_observatory.py:279: RuntimeWarning: invalid value encountered in less
#   slewtimes[np.where(slewtimes < 0)] = np.nan
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/modelObservatory/model_observatory.py:441: UserWarning: overriding requested rotSkyPos value
#   warnings.warn('overriding requested rotSkyPos value')
# progress = 100.1%Skipped 0 observations
# Flushed 0 observations from queue for being stale
# Completed 24960 observations
# ran in 8 min = 0.1 hours
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/sim_runner.py:98: UserWarning: Failed to get info about run, may need to run scons in some pacakges.
#   warnings.warn('Failed to get info about run, may need to run scons in some pacakges.')
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['observationStartMJD', 'night', 'altitude', 'azimuth', 'filter'].
# Found 24960 visits
# Running:  ['HeavySlew_Count_observationStartMJD_HEAL']
# Completed metric generation.
# Running:  ['HeavySlew_Hourglass_HOUR']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter = "g" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 14878 visits
# Running:  ['HeavySlew_Count_observationStartMJD_g_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter = "z" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 10082 visits
# Running:  ['HeavySlew_Count_observationStartMJD_z_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# Plotting complete.
# Plotting figures with "filter = "g"" constraint now.
# Plotting complete.
# Plotting figures with "filter = "z"" constraint now.
# Plotting complete.

# %%
#Now to ephasize m5
runName = 'HeavyM5'
weights = {'m5_weight': 30,
          'count_uniformity_weight' : 0.3,
           'slewtime_weight': 3., 'filter_change_weight': 4.}
filters = ['g', 'z']

run_sim(runName, weights, filters)
# Out:
# WARNING: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)" [astropy._erfa.core]
# WARNING:astropy:ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
# /Users/yoachim/gitRepos/sims_skybrightness_pre/python/lsst/sims/skybrightness_pre/SkyModelPre.py:370: UserWarning: Requested MJD between sunrise and sunset, returning closest maps
#   warnings.warn('Requested MJD between sunrise and sunset, returning closest maps')
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/modelObservatory/model_observatory.py:279: RuntimeWarning: invalid value encountered in less
#   slewtimes[np.where(slewtimes < 0)] = np.nan
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/modelObservatory/model_observatory.py:441: UserWarning: overriding requested rotSkyPos value
#   warnings.warn('overriding requested rotSkyPos value')
# progress = 100.1%Skipped 0 observations
# Flushed 0 observations from queue for being stale
# Completed 24059 observations
# ran in 8 min = 0.1 hours
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/sim_runner.py:98: UserWarning: Failed to get info about run, may need to run scons in some pacakges.
#   warnings.warn('Failed to get info about run, may need to run scons in some pacakges.')
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['observationStartMJD', 'night', 'altitude', 'azimuth', 'filter'].
# Found 24059 visits
# Running:  ['HeavyM5_Count_observationStartMJD_HEAL']
# Completed metric generation.
# Running:  ['HeavyM5_Hourglass_HOUR']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter = "g" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 13563 visits
# Running:  ['HeavyM5_Count_observationStartMJD_g_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter = "z" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 10496 visits
# Running:  ['HeavyM5_Count_observationStartMJD_z_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# Plotting complete.
# Plotting figures with "filter = "g"" constraint now.
# Plotting complete.
# Plotting figures with "filter = "z"" constraint now.
# Plotting complete.

# %%
# very uniform survey
runName = 'HeavyUniform'
weights = {'m5_weight': 3,
          'count_uniformity_weight' : 5,
           'slewtime_weight': 3., 'filter_change_weight': 4.}
filters = ['g', 'z']

run_sim(runName, weights, filters)
# Out:
# WARNING: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)" [astropy._erfa.core]
# WARNING:astropy:ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
# /Users/yoachim/gitRepos/sims_skybrightness_pre/python/lsst/sims/skybrightness_pre/SkyModelPre.py:370: UserWarning: Requested MJD between sunrise and sunset, returning closest maps
#   warnings.warn('Requested MJD between sunrise and sunset, returning closest maps')
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/modelObservatory/model_observatory.py:279: RuntimeWarning: invalid value encountered in less
#   slewtimes[np.where(slewtimes < 0)] = np.nan
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/modelObservatory/model_observatory.py:441: UserWarning: overriding requested rotSkyPos value
#   warnings.warn('overriding requested rotSkyPos value')
# progress = 100.1%Skipped 0 observations
# Flushed 0 observations from queue for being stale
# Completed 23206 observations
# ran in 7 min = 0.1 hours
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/sim_runner.py:98: UserWarning: Failed to get info about run, may need to run scons in some pacakges.
#   warnings.warn('Failed to get info about run, may need to run scons in some pacakges.')
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['observationStartMJD', 'night', 'altitude', 'azimuth', 'filter'].
# Found 23206 visits
# Running:  ['HeavyUniform_Count_observationStartMJD_HEAL']
# Completed metric generation.
# Running:  ['HeavyUniform_Hourglass_HOUR']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter = "g" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 14809 visits
# Running:  ['HeavyUniform_Count_observationStartMJD_g_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter = "z" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 8397 visits
# Running:  ['HeavyUniform_Count_observationStartMJD_z_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# Plotting complete.
# Plotting figures with "filter = "g"" constraint now.
# Plotting complete.
# Plotting figures with "filter = "z"" constraint now.
# Plotting complete.

# %%
#Supress filter changes a lot (still "free" at moonrise/set and twilight start/end)
runName = 'HeavyFilterChange'
weights = {'m5_weight': 3,
          'count_uniformity_weight' : 0.3,
           'slewtime_weight': 3., 'filter_change_weight': 10.}
filters = ['g', 'z']
run_sim(runName, weights, filters)
# Out:
# WARNING: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)" [astropy._erfa.core]
# WARNING:astropy:ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
# /Users/yoachim/gitRepos/sims_skybrightness_pre/python/lsst/sims/skybrightness_pre/SkyModelPre.py:370: UserWarning: Requested MJD between sunrise and sunset, returning closest maps
#   warnings.warn('Requested MJD between sunrise and sunset, returning closest maps')
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/modelObservatory/model_observatory.py:279: RuntimeWarning: invalid value encountered in less
#   slewtimes[np.where(slewtimes < 0)] = np.nan
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/modelObservatory/model_observatory.py:441: UserWarning: overriding requested rotSkyPos value
#   warnings.warn('overriding requested rotSkyPos value')
# progress = 100.1%Skipped 0 observations
# Flushed 0 observations from queue for being stale
# Completed 24621 observations
# ran in 8 min = 0.1 hours
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/sim_runner.py:98: UserWarning: Failed to get info about run, may need to run scons in some pacakges.
#   warnings.warn('Failed to get info about run, may need to run scons in some pacakges.')
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['observationStartMJD', 'night', 'altitude', 'azimuth', 'filter'].
# Found 24621 visits
# Running:  ['HeavyFilterChange_Count_observationStartMJD_HEAL']
# Completed metric generation.
# Running:  ['HeavyFilterChange_Hourglass_HOUR']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter = "g" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 15092 visits
# Running:  ['HeavyFilterChange_Count_observationStartMJD_g_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter = "z" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 9529 visits
# Running:  ['HeavyFilterChange_Count_observationStartMJD_z_HEAL']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Plotting figures with "" constraint now.
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3608: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /Users/yoachim/lsstp3/python/miniconda3-4.3.21/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:3677: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# Plotting complete.
# Plotting figures with "filter = "g"" constraint now.
# Plotting complete.
# Plotting figures with "filter = "z"" constraint now.
# Plotting complete.

# %%
#Let filter changes a lot. (White on hourglass can happen when filter thrashing)
runName = 'LightFilterChange'
weights = {'m5_weight': 3,
          'count_uniformity_weight' : 0.3,
           'slewtime_weight': 3., 'filter_change_weight': 0.0}
filters = ['g', 'z']
run_sim(runName, weights, filters)
# Out:
# WARNING: ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)" [astropy._erfa.core]
# WARNING:astropy:ErfaWarning: ERFA function "d2dtf" yielded 1 of "dubious year (Note 5)"
# /Users/yoachim/gitRepos/sims_skybrightness_pre/python/lsst/sims/skybrightness_pre/SkyModelPre.py:370: UserWarning: Requested MJD between sunrise and sunset, returning closest maps
#   warnings.warn('Requested MJD between sunrise and sunset, returning closest maps')
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/modelObservatory/model_observatory.py:279: RuntimeWarning: invalid value encountered in less
#   slewtimes[np.where(slewtimes < 0)] = np.nan
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/modelObservatory/model_observatory.py:441: UserWarning: overriding requested rotSkyPos value
#   warnings.warn('overriding requested rotSkyPos value')
# progress = 100.1%Skipped 0 observations
# Flushed 0 observations from queue for being stale
# Completed 24003 observations
# ran in 7 min = 0.1 hours
# /Users/yoachim/gitRepos/sims_featureScheduler/python/lsst/sims/featureScheduler/sim_runner.py:98: UserWarning: Failed to get info about run, may need to run scons in some pacakges.
#   warnings.warn('Failed to get info about run, may need to run scons in some pacakges.')
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=128, approximate resolution 27.483891 arcminutes
# Healpix slicer using NSIDE=64, approximate resolution 54.967783 arcminutes
# Querying database SummaryAllProps with no constraint for columns ['observationStartMJD', 'night', 'altitude', 'azimuth', 'filter'].
# Found 24003 visits
# Running:  ['LightFilterChange_Count_observationStartMJD_HEAL']
# Completed metric generation.
# Running:  ['LightFilterChange_Hourglass_HOUR']
# Completed metric generation.
# Running reduce methods.
# Running summary statistics.
# Completed.
# Querying database SummaryAllProps with constraint filter = "g" for columns ['fieldRA', 'observationStartMJD', 'fieldDec']
# Found 14458 visits
# Running:  ['LightFilterChange_Count_observationStartMJD_g_HEAL']
